# %%
import cv2
import matplotlib.pyplot as plt

# %%
#checking version
print(cv2.__version__)
# Out:
# 4.1.0

# %%
# image reading
img=cv2.imread('download.jpeg',1)
img1=cv2.imread('download.jpeg',0)
# 1 means image in same color channel --GRB OR RGB
# 0 means no color channel -- Black & White ---Gray image
# -1 maintain image transparency ---

# %%
img
# Out:
# array([[[198, 124,  46],
#         [198, 124,  46],
#         [198, 124,  46],
#         ...,
#         [206, 140,  81],
#         [206, 140,  81],
#         [206, 140,  81]],
#
#        [[198, 124,  46],
#         [198, 124,  46],
#         [198, 124,  46],
#         ...,
#         [206, 140,  81],
#         [206, 140,  81],
#         [206, 140,  81]],
#
#        [[198, 124,  46],
#         [198, 124,  46],
#         [198, 124,  46],
#         ...,
#         [207, 141,  82],
#         [207, 141,  82],
#         [207, 141,  82]],
#
#        ...,
#
#        [[189, 177, 167],
#         [189, 177, 165],
#         [189, 177, 167],
#         ...,
#         [210, 201, 198],
#         [210, 201, 198],
#         [210, 201, 198]],
#
#        [[196, 185, 177],
#         [196, 186, 176],
#         [195, 184, 176],
#         ...,
#         [210, 201, 198],
#         [210, 201, 198],
#         [210, 201, 198]],
#
#        [[211, 202, 193],
#         [211, 202, 193],
#         [211, 202, 193],
# ...

# %%
#type of image
type(img)
# Out:
# numpy.ndarray

# %%
#print shape
img.shape
# Out:
# (194, 259, 3)

# %%
# display image
#cv2.imshow('download.jpeg',img)

# %%
plt.imshow(img1)

# %%
plt.imshow(img)

# %%
plt.imshow(img1)

# %%
# split into BGR
x,y,z=cv2.split(img)

# %%
plt.imshow(x)

# %%
plt.imshow(y)

# %%
plt.imshow(z)

# %%
#drawing line
cv2.line(img,(0,0),(150,160),(0,0,255),3)
plt.imshow(img)

# %%
cv2.rectangle(img,(50,80),(150,160),(255,0,0),-1)
plt.imshow(img)
